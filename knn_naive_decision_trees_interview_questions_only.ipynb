# %% [markdown]
# # KNN, Naive Bayes & Decision Trees — Interview Questions
# **Instructions:** Answer each question in the cell below it. For coding questions, write your solution in the provided code cell.
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris, load_breast_cancer, make_classification
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import warnings
warnings.filterwarnings('ignore')

print('Libraries loaded')

# %% [markdown]
# ---
# # PART 1: K-Nearest Neighbors (KNN)
# ---

# %% [markdown]
# ## Conceptual Questions

# %% [markdown]
# ### Q1. What is the KNN algorithm? Explain step by step how it makes predictions for classification.

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q2. Why is feature scaling critical in KNN? Give a concrete example of what happens without it.

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q3. How do you choose the optimal value of K? What happens when K is too small or too large?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q4. List and explain at least 4 distance metrics used in KNN. When would you use each?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q5. What are the main disadvantages of KNN? What is the curse of dimensionality?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q6. KNN is called a "lazy learner". What does this mean? What is the trade-off compared to eager learners?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ## Coding Questions

# %% [markdown]
# ### Coding Q1: Implement KNN from scratch using only NumPy (no sklearn). Test it on the Iris dataset and compare accuracy with sklearn's KNeighborsClassifier.

# %%
# Your implementation here

# %% [markdown]
# ### Coding Q2: Use cross-validation to find the optimal K for the Iris dataset. Plot train error vs validation error vs K (Elbow Method). Print the optimal K.

# %%
# Your implementation here

# %% [markdown]
# ### Coding Q3: Create a synthetic dataset with two features at very different scales (e.g., age 0–100, income 0–1,000,000). Demonstrate the impact of StandardScaler on KNN accuracy by comparing performance with and without scaling.

# %%
# Your implementation here

# %% [markdown]
# ### Coding Q4: Implement weighted KNN where closer neighbors have higher influence (weights='distance'). Compare accuracy with uniform weights on the breast cancer dataset.

# %%
# Your implementation here

# %% [markdown]
# ---
# # PART 2: Naive Bayes
# ---

# %% [markdown]
# ## Conceptual Questions

# %% [markdown]
# ### Q1. Explain the Naive Bayes algorithm. Write the Bayes Theorem formula and define each term. What makes it "naive"?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q2. What are the three main variants of Naive Bayes? When would you use each one?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q3. What is the zero-frequency problem in Naive Bayes? How does Laplace Smoothing solve it? Write the formula.

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q4. Why does Naive Bayes work well for text classification even though the independence assumption is violated?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q5. What are the main limitations of Naive Bayes? Give a real-world example where it would fail.

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q6. Why do we use log probabilities when computing the posterior in Naive Bayes? What problem does this prevent?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ## Coding Questions

# %% [markdown]
# ### Coding Q1: Implement Gaussian Naive Bayes from scratch. Your class must: (a) compute class priors, (b) compute per-class mean and std for each feature, (c) use log-likelihood to avoid numerical underflow, (d) predict class labels. Compare with sklearn's GaussianNB.

# %%
# Your implementation here

# %% [markdown]
# ### Coding Q2: Build a spam email classifier using MultinomialNB with CountVectorizer. Use the sample emails below. Show: (a) accuracy, (b) predictions with probabilities for two new emails.

# %%
emails = [
    'win free money now click here',
    'congratulations you won a prize claim now',
    'free offer limited time buy now',
    'earn money from home fast cash',
    'click to claim your free prize today',
    'urgent winner selected claim prize immediately',
    'make money fast work from home',
    'special offer buy now save money',
    'meeting scheduled for tomorrow morning',
    'please review the attached project report',
    'can we reschedule our call to afternoon',
    'team lunch this friday at noon',
    'your code review has been approved',
    'please submit the expense report by friday',
    'quarterly review meeting is next monday',
    'thank you for your help on this project',
]
labels = [1]*8 + [0]*8  # 1=spam, 0=ham

# Your implementation here

# %% [markdown]
# ### Coding Q3: Plot the decision boundary of GaussianNB on a 2D dataset (make_blobs with 3 classes). Compare it side by side with KNN (k=5) on the same data.

# %%
# Your implementation here

# %% [markdown]
# ---
# # PART 3: Decision Trees
# ---

# %% [markdown]
# ## Conceptual Questions

# %% [markdown]
# ### Q1. How does a Decision Tree decide which feature and threshold to split on? Explain Information Gain.

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q2. Write the formulas for Gini Impurity and Entropy. What is the key difference between them? Which does sklearn use by default?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q3. What is overfitting in Decision Trees? List at least 4 hyperparameters that control overfitting and explain how each one works.

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q4. What is post-pruning (cost-complexity pruning)? How does the `ccp_alpha` parameter work?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q5. What is the time complexity for training and predicting with a Decision Tree? Why is prediction so fast?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q6. Can sklearn's Decision Tree handle missing values or raw categorical features natively? How would you handle them?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ## Coding Questions

# %% [markdown]
# ### Coding Q1: Implement Gini Impurity, Entropy, and Information Gain from scratch using NumPy. Demonstrate with a perfect split and a bad split — show that IG is maximized for the perfect split.

# %%
# Your implementation here

# %% [markdown]
# ### Coding Q2: Train a Decision Tree on the Iris dataset (max_depth=3). Visualize the tree using plot_tree. Print the text representation and feature importances.

# %%
# Your implementation here

# %% [markdown]
# ### Coding Q3: Plot train accuracy vs test accuracy as a function of max_depth (1 to 20) on the breast cancer dataset. Identify the depth where overfitting begins. Mark the optimal depth on the plot.

# %%
# Your implementation here

# %% [markdown]
# ### Coding Q4: Use GridSearchCV to find the best hyperparameters for a Decision Tree on the breast cancer dataset. Search over: `max_depth`, `min_samples_split`, `min_samples_leaf`, and `criterion`.

# %%
# Your implementation here

# %% [markdown]
# ### Coding Q5: Apply cost-complexity pruning to a Decision Tree. Plot accuracy vs ccp_alpha and tree size vs ccp_alpha. Find the optimal alpha.

# %%
# Your implementation here

# %% [markdown]
# ---
# # PART 4: Comparison & Advanced Questions
# ---

# %% [markdown]
# ## Conceptual Questions

# %% [markdown]
# ### Q1. Fill in this comparison table:
#
# | Property | KNN | Naive Bayes | Decision Tree |
# |----------|-----|-------------|---------------|
# | Training time complexity | | | |
# | Prediction time complexity | | | |
# | Feature scaling required? | | | |
# | Handles non-linear boundaries? | | | |
# | Interpretable? | | | |
# | Sensitive to outliers? | | | |
# | Key hyperparameter | | | |

# %% [markdown]
# **Your Answer:** *(edit the table above)*

# %% [markdown]
# ### Q2. For each scenario below, choose the best algorithm and justify your choice:
#
# a) Real-time spam email classification on a server handling 10,000 emails/second
# b) A bank wants a model that shows customers exactly why their loan was denied
# c) Product recommendation system with 50,000 users and 100 features
# d) Medical diagnosis on a small dataset of 200 patients, 20 features

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q3. How does each algorithm handle the bias-variance tradeoff? Which has the highest variance by default and why?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q4. What is the relationship between Decision Trees and Random Forests? How does Random Forest fix the main weakness of a single Decision Tree?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q5. How would you handle a highly imbalanced dataset (e.g., 95% class 0, 5% class 1) with each of the three algorithms?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ### Q6. Can KNN be used for regression? How does the prediction mechanism change? What are the trade-offs?

# %% [markdown]
# **Your Answer:**

# %% [markdown]
# ## Coding Questions

# %% [markdown]
# ### Coding Q1: Benchmark all three models (KNN, GaussianNB, DecisionTree) on the breast cancer dataset. Report accuracy, ROC-AUC, and 5-fold CV score for each. Plot ROC curves for all three on the same chart.

# %%
# Your implementation here

# %% [markdown]
# ### Coding Q2: Create an imbalanced dataset (weights=[0.9, 0.1]). For each algorithm, compare the default version against the class-imbalance-aware version (KNN: distance weights, NB: manual priors, DT: class_weight='balanced'). Report accuracy and ROC-AUC.

# %%
# Your implementation here

# %% [markdown]
# ### Coding Q3 (Bonus): Build a Pipeline for each model that includes preprocessing (StandardScaler where needed) and use cross_val_score to evaluate. Which pipeline gives the best mean CV accuracy?

# %%
# Your implementation here
